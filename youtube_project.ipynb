# %%
# !pip install yt-dlp
import yt_dlp


def download_video(url, resolution='highest'):
    try:
        # Set yt-dlp options for video download
        ydl_opts = {
            'format': f'bestvideo[height<={resolution}]+bestaudio/best[height<={resolution}]' if resolution != 'highest' else 'best',
            'outtmpl': '%(title)s.%(ext)s',  # Output file name template
        }

        # Download video with yt-dlp
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        print("Download completed!")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    video_url = input("Enter YouTube URL: ")
    video_resolution = input("Enter resolution (e.g., 720p or leave blank for highest): ").strip()

    # Download the video with specified resolution
    download_video(video_url, video_resolution or 'highest')
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2025.1.26-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 7.1 MB/s eta 0:00:00
# Downloading yt_dlp-2025.1.26-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 70.4 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.1.26
# Enter YouTube URL: https://youtu.be/tDTfdsbo3uI?si=TJz-zMzvqwzX2svB
# Enter resolution (e.g., 720p or leave blank for highest): 720p
# [youtube] Extracting URL: https://youtu.be/tDTfdsbo3uI?si=TJz-zMzvqwzX2svB
# [youtube] tDTfdsbo3uI: Downloading webpage
# [youtube] tDTfdsbo3uI: Downloading tv client config
# [youtube] tDTfdsbo3uI: Downloading player 1080ef44
# [youtube] tDTfdsbo3uI: Downloading tv player API JSON
# [youtube] tDTfdsbo3uI: Downloading ios player API JSON
# [youtube] tDTfdsbo3uI: Downloading m3u8 information
# [info] tDTfdsbo3uI: Downloading 1 format(s): 616+251
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 114
# [download] Destination: Best Girlfriend (Short Film).f616.mp4
# [download] 100% of  135.79MiB in 00:00:18 at 7.26MiB/s
# [download] Destination: Best Girlfriend (Short Film).f251.webm
# [download] 100% of    7.66MiB in 00:00:00 at 32.85MiB/s
# [Merger] Merging formats into "Best Girlfriend (Short Film).webm"
# Deleting original file Best Girlfriend (Short Film).f251.webm (pass -k to keep)
# Deleting original file Best Girlfriend (Short Film).f616.mp4 (pass -k to keep)
# Download completed!
